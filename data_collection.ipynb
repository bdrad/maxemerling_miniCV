# %%
import pydicom as dicom
import os
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt, cm
from skimage import transform, io

# %%
def read_dcm(path):
    file = dicom.dcmread(path)
    
    return file.pixel_array

def read_png(path):
    return io.imread(path)

def resize(img, dims):
    return transform.resize(img, dims, mode='reflect')

# %%
def load(path, dims=None):
    name, ext = os.path.splitext(path)
    if ext.lower() == '.dcm':
        pixels = read_dcm(path)
    elif ext.lower() == '.png':
        pixels = read_png(path)
    else:
        return None
    
    if dims:
        return resize(pixels, dims)
    else:
        return pixels

# %%
def display(pixels):
    plt.figure()
    plt.imshow(pixels)

# %%
def get_dicoms(path):
    """gets all dicom files under the given path, in all subfolders and returns a list of their paths"""

    dcm_lst = []
    for dir_name, subdir_lst, file_lst in os.walk(path):
        for file in file_lst:
            name, ext = os.path.splitext(file)
            if ext.lower() == '.dcm':
                dcm_lst.append(os.path.join(dir_name, file))
    
    return dcm_lst

# %%
import csv

def csv_to_dict(path, key_header, val_header, name_key):
    reader = csv.reader(open(path))
    headers = next(reader)
    key_idx, val_idx = headers.index(key_header), headers.index(val_header)
    
    d = {}
    for row in reader:
        d[get_img_name(row[key_idx], name_key)] = row[val_idx]
    
    return d
    

train_key, test_key = 'Mass-Training', 'Mass-Test'
path_header = 'image file path'
density_header = 'breast_density'

def get_img_name(path, key):
    for sub in path.split('/'):
        if key in sub:
            return sub
    return None

# %%
def combine_and_save(out_folder, dcm_lst, label_dict, name_key, dims):
    """
    Combines images with their given labels.
    Set density levels 1 and 2 to 'not dense' = 0
    Set density levels 3 and 4 to 'dense' = 1
    """
    
    exampleList, labelList = [], []
    
    i = 0
    for dicom in dcm_lst:
        name = get_img_name(dicom, name_key)
        pixels = load(dicom, dims)
        
        exampleList.append(pixels)
        
        label = label_dict[name]
        labelList.append(label)
        
        i += 1
        print("{0} out of {1} processed. {2}% complete".format(i, len(dcm_lst), int(100 * i/len(dcm_lst))))
    
    save(out_folder, '{}-Examples'.format(name_key), np.array(exampleList) / UINT16_MAX_VALUE)
    save(out_folder, '{}-Labels'.format(name_key), np.array(labelList))

def save(folder, name, arr):
    np.savez(folder + '/' + name, arr)

# %%
RESNET_INPUT_SIZE = (224, 224)
UINT16_MAX_VALUE = 65535
NUM_CLASSES = SPLIT = 2

def convert_data(images_path, labels_path, out_folder, name_key, 
                 key_header=path_header, val_header=density_header, dims=RESNET_INPUT_SIZE):
    
    dcm_lst = get_dicoms(images_path)
    label_dict = csv_to_dict(labels_path, key_header, val_header, name_key)
    combine_and_save(out_folder, dcm_lst, label_dict, name_key, dims)

# %%
train_img_path, test_img_path = 'Train', 'Test'
train_labels_path, test_labels_path = 'Mass-Training-Description.csv', 'Mass-Testing-Description.csv'
out = 'processed'

if not os.path.isdir(out):
    os.mkdir(out)

convert_data(train_img_path, train_labels_path, out, train_key)

print("Done with train")

convert_data(test_img_path, test_labels_path, out, test_key)

print("Done with test")
# Out:
# 1 out of 354 processed. 0% complete
# 2 out of 354 processed. 0% complete
# 342 out of 354 processed. 96% complete
# 343 out of 354 processed. 96% complete
# 344 out of 354 processed. 97% complete
# 345 out of 354 processed. 97% complete
# 346 out of 354 processed. 97% complete
# 347 out of 354 processed. 98% complete
# 348 out of 354 processed. 98% complete
# 349 out of 354 processed. 98% complete
# 350 out of 354 processed. 98% complete
# 351 out of 354 processed. 99% complete
# 352 out of 354 processed. 99% complete
# 353 out of 354 processed. 99% complete
# 354 out of 354 processed. 100% complete
# Done with train
# 1 out of 156 processed. 0% complete
# 2 out of 156 processed. 1% complete
# 3 out of 156 processed. 1% complete
# 4 out of 156 processed. 2% complete
# 5 out of 156 processed. 3% complete
# 6 out of 156 processed. 3% complete
# 7 out of 156 processed. 4% complete
# 8 out of 156 processed. 5% complete
# 9 out of 156 processed. 5% complete
# 10 out of 156 processed. 6% complete
# 11 out of 156 processed. 7% complete
# 12 out of 156 processed. 7% complete
# 13 out of 156 processed. 8% complete
# 14 out of 156 processed. 8% complete
# 15 out of 156 processed. 9% complete
# 16 out of 156 processed. 10% complete
# 17 out of 156 processed. 10% complete
# 18 out of 156 processed. 11% complete
# 19 out of 156 processed. 12% complete
# 20 out of 156 processed. 12% complete
# 21 out of 156 processed. 13% complete
# 22 out of 156 processed. 14% complete
# 23 out of 156 processed. 14% complete
# 24 out of 156 processed. 15% complete
# 25 out of 156 processed. 16% complete
# 26 out of 156 processed. 16% complete
# 27 out of 156 processed. 17% complete
# 28 out of 156 processed. 17% complete
# 29 out of 156 processed. 18% complete
# 30 out of 156 processed. 19% complete
# 31 out of 156 processed. 19% complete
# 32 out of 156 processed. 20% complete
# 33 out of 156 processed. 21% complete
# 34 out of 156 processed. 21% complete
# 35 out of 156 processed. 22% complete
# 36 out of 156 processed. 23% complete
# 37 out of 156 processed. 23% complete
# 38 out of 156 processed. 24% complete
# 39 out of 156 processed. 25% complete
# 40 out of 156 processed. 25% complete
# 41 out of 156 processed. 26% complete
# 42 out of 156 processed. 26% complete
# 43 out of 156 processed. 27% complete
# 44 out of 156 processed. 28% complete
# 45 out of 156 processed. 28% complete
# 46 out of 156 processed. 29% complete
# 47 out of 156 processed. 30% complete
# 48 out of 156 processed. 30% complete
# 49 out of 156 processed. 31% complete
# 50 out of 156 processed. 32% complete
# 51 out of 156 processed. 32% complete
# 52 out of 156 processed. 33% complete
# 53 out of 156 processed. 33% complete
# 54 out of 156 processed. 34% complete
# 55 out of 156 processed. 35% complete
# 56 out of 156 processed. 35% complete
# 57 out of 156 processed. 36% complete
# 58 out of 156 processed. 37% complete
# 59 out of 156 processed. 37% complete
# 60 out of 156 processed. 38% complete
# 61 out of 156 processed. 39% complete
# 62 out of 156 processed. 39% complete
# 63 out of 156 processed. 40% complete
# 64 out of 156 processed. 41% complete
# 65 out of 156 processed. 41% complete
# 66 out of 156 processed. 42% complete
# 67 out of 156 processed. 42% complete
# 68 out of 156 processed. 43% complete
# 69 out of 156 processed. 44% complete
# 70 out of 156 processed. 44% complete
# 71 out of 156 processed. 45% complete
# 72 out of 156 processed. 46% complete
# 73 out of 156 processed. 46% complete
# 74 out of 156 processed. 47% complete
# 75 out of 156 processed. 48% complete
# 76 out of 156 processed. 48% complete
# 77 out of 156 processed. 49% complete
# 78 out of 156 processed. 50% complete
# 79 out of 156 processed. 50% complete
# 80 out of 156 processed. 51% complete
# 81 out of 156 processed. 51% complete
# 82 out of 156 processed. 52% complete
# 83 out of 156 processed. 53% complete
# 84 out of 156 processed. 53% complete
# 85 out of 156 processed. 54% complete
# 86 out of 156 processed. 55% complete
# 87 out of 156 processed. 55% complete
# 88 out of 156 processed. 56% complete
# 89 out of 156 processed. 57% complete
# 90 out of 156 processed. 57% complete
# 91 out of 156 processed. 58% complete
# 92 out of 156 processed. 58% complete
# 93 out of 156 processed. 59% complete
# 94 out of 156 processed. 60% complete
# 95 out of 156 processed. 60% complete
# 96 out of 156 processed. 61% complete
# 97 out of 156 processed. 62% complete
# 98 out of 156 processed. 62% complete
# 99 out of 156 processed. 63% complete
# 100 out of 156 processed. 64% complete
# 101 out of 156 processed. 64% complete
# 102 out of 156 processed. 65% complete
# 103 out of 156 processed. 66% complete
# 104 out of 156 processed. 66% complete
# 105 out of 156 processed. 67% complete
# 106 out of 156 processed. 67% complete
# 107 out of 156 processed. 68% complete
# 108 out of 156 processed. 69% complete
# 109 out of 156 processed. 69% complete
# 110 out of 156 processed. 70% complete
# 111 out of 156 processed. 71% complete
# 112 out of 156 processed. 71% complete
# 113 out of 156 processed. 72% complete
# 114 out of 156 processed. 73% complete
# 115 out of 156 processed. 73% complete
# 116 out of 156 processed. 74% complete
# 117 out of 156 processed. 75% complete
# 118 out of 156 processed. 75% complete
# 119 out of 156 processed. 76% complete
# 120 out of 156 processed. 76% complete
# 121 out of 156 processed. 77% complete
# 122 out of 156 processed. 78% complete
# 123 out of 156 processed. 78% complete
# 124 out of 156 processed. 79% complete
# 125 out of 156 processed. 80% complete
# 126 out of 156 processed. 80% complete
# 127 out of 156 processed. 81% complete
# 128 out of 156 processed. 82% complete
# 129 out of 156 processed. 82% complete
# 130 out of 156 processed. 83% complete
# 131 out of 156 processed. 83% complete
# 132 out of 156 processed. 84% complete
# 133 out of 156 processed. 85% complete
# 134 out of 156 processed. 85% complete
# 135 out of 156 processed. 86% complete
# 136 out of 156 processed. 87% complete
# 137 out of 156 processed. 87% complete
# 138 out of 156 processed. 88% complete
# 139 out of 156 processed. 89% complete
# 140 out of 156 processed. 89% complete
# 141 out of 156 processed. 90% complete
# 142 out of 156 processed. 91% complete
# 143 out of 156 processed. 91% complete
# 144 out of 156 processed. 92% complete
# 145 out of 156 processed. 92% complete
# 146 out of 156 processed. 93% complete
# 147 out of 156 processed. 94% complete
# 148 out of 156 processed. 94% complete
# 149 out of 156 processed. 95% complete
# 150 out of 156 processed. 96% complete
# 151 out of 156 processed. 96% complete
# 152 out of 156 processed. 97% complete
# 153 out of 156 processed. 98% complete
# 154 out of 156 processed. 98% complete
# 155 out of 156 processed. 99% complete
# 156 out of 156 processed. 100% complete
# Done with test
